# %%
#DEMI5TFZE7ACXMV35LDUH7XQ-BO2AFU2NYQE3OIDQ
# !pip install anvil-uplink
import pandas as pd
import numpy as np

from anvil.tables import app_tables
import anvil.server
import anvil.media

anvil.server.connect("DEMI5TFZE7ACXMV35LDUH7XQ-BO2AFU2NYQE3OIDQ") 

def _upload_dataframe(df, rows):
    df = df.replace({np.nan: None})
    dicts = df.to_dict(orient="records")
    if rows:
        dicts = list(dicts)[:rows]
    if len(dicts) < 200:
        # This way is faster:
        anvil.server.call('save_to_table', dicts)
    else:
        # But keep large file processing here to avoid server timeouts:
        for d in dicts:
            app_tables.my_table.add_row(**d)

@anvil.server.callable
def upload_csv_data(file, rows=None):
    with anvil.media.TempFile(file) as f:
        df = pd.read_csv(f)
        _upload_dataframe(df, rows)

@anvil.server.callable
def upload_excel_data(file, rows=None):
    with anvil.media.TempFile(file) as f:
        df = pd.read_excel(f)
        _upload_dataframe(df, rows)

anvil.server.wait_forever()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting anvil-uplink
#   Downloading anvil_uplink-0.4.1-py2.py3-none-any.whl (87 kB)
#      |████████████████████████████████| 87 kB 2.5 MB/s
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from anvil-uplink) (0.16.0)
# Collecting argparse
#   Downloading argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from anvil-uplink) (1.15.0)
# Collecting ws4py
#   Downloading ws4py-0.5.1.tar.gz (51 kB)
#      |████████████████████████████████| 51 kB 107 kB/s
# Building wheels for collected packages: ws4py
#   Building wheel for ws4py (setup.py) ... done
#   Created wheel for ws4py: filename=ws4py-0.5.1-py3-none-any.whl size=45229 sha256=c64cbe13fa13980ff0d20c4ec1bca17358aa831a2b24bfa068a6e60f4ef7450a
#   Stored in directory: /root/.cache/pip/wheels/29/ea/7d/3410aa0aa0e4402ead9a7a97ab2214804887e0f5c2b76f0c96
# Successfully built ws4py
# Installing collected packages: ws4py, argparse, anvil-uplink
# Successfully installed anvil-uplink-0.4.1 argparse-1.4.0 ws4py-0.5.1
# Connecting to wss://anvil.works/uplink
# Anvil websocket open
# Connected to "Default environment" as SERVER
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-9eaed65d998b> in <module>
#      35         _upload_dataframe(df, rows)
#      36
# ---> 37 anvil.server.wait_forever()
#
# /usr/local/lib/python3.7/dist-packages/anvil/server.py in wait_forever()
#     432     _get_connection()
#     433     while True:
# --> 434         time.sleep(1)
#
# KeyboardInterrupt:
