# %%
import pandas as pd
# Out:
# 2.9.2

# %%
from google.colab import drive
drive.mount('/content/gdrive')
import sys    
root_path = 'gdrive/My Drive/Colab Notebooks/'
sys.path.append(root_path)
from Model1 import myfunc
# Out:
# Mounted at /content/gdrive
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-287494675327> in <module>
#       4 root_path = 'gdrive/My Drive/Colab Notebooks/'
#       5 sys.path.append(root_path)
# ----> 6 from Model1 import myfunc
#
# ImportError: cannot import name 'myfunc' from 'Model1' (gdrive/My Drive/Colab Notebooks/Model1.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
ordinary_tweets_data = load_data()

# %%
from google.colab import drive
drive.mount('/content/gdrive')

root_path = 'gdrive/My Drive/Colab Notebooks/'

myfunc('gdrive/My Drive/Colab Notebooks/srilanka_easter.csv')
