# %%
import tweepy
import csv
import pandas as pd
import sys
import numpy as np

# %%
from importlib import reload
reload(sys)
# Out:
# <module 'sys' (built-in)>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#### input your credentials here
consumer_key = 'CQldZWCZjOPCmcuggVEYDLKb8'
consumer_secret = 'rVGwBrR5PKxZs2yIpwPIbLP6TzhARo7C4cRodrCKVFSEGTOOWi'
access_token = '1506450127057305604-XjukkZt3QPyCQ8oZTRC4qpQnglQu4u'
access_token_secret = 'xY7v8pWdKZaQcGGVokNQIwgwoiMSlmZlbn6nWAaytJxN2'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit = True)

# %% [markdown]
# testing

# %%
# Load dataset
def load_data():
    data = pd.read_csv("gdrive/My Drive/Colab Notebooks/srilanka_easter.csv")
    data.columns = data.columns.str.replace(' ','_')
    return data

# %%
tweet_df = load_data()
tweet_df.head(2)
# Out:
#                 Tweet_Id                                          Tweet_URL  \
# 0  "1130420279627395072"  https://twitter.com/HotelierME/status/11304202...
# 1  "1130150275766001664"  https://twitter.com/ImtiazsharPYO/status/11301...
#
#   Tweet_Posted_Time_(UTC)                                      Tweet_Content  \
# 0    20 May 2019 10:29:31  #SriLanka #hotel occupancy drops following #Ea...
# 1    19 May 2019 16:36:37  RT @BBhuttoZardari: Devastating news coming ou...
#
#   Tweet_Type                 Client  Retweets_Received  Favourites_Received  \
# 0      Tweet  Fanbooster by Traject                  0                    0
# 1    ReTweet    Twitter for Android                  0                    0
#
#          Tweet_Location Tweet_Language  ...    Screen_Name  \
# 0  United Arab Emirates        English  ...     HotelierME
# 1       Sindh, Pakistan        English  ...  ImtiazsharPYO
#
#                                             User_Bio Verified_or_Non-Verified  \
# ...

# %%
pattern='Colombo,Sri Lanka |Colombo, Sri Lanka|Sri Lanka| Srilanka ðŸ‡±ðŸ‡° |Colombo|Colombo, Srilanka|Colombo Sri Lanka|Sri Lankan'

mask=tweet_df['Tweet_Location'].str.contains(pattern,case=False,na=False)
tweet_df1=tweet_df[mask]
tweet_df1
# Out:
#                     Tweet_Id  \
# 3      "1130097107333836800"
# 4      "1130043387724353536"
# 10     "1129755645698297857"
# 13     "1129449756512727040"
# 14     "1129435664393691138"
# ...                      ...
# 10952  "1119811434756673536"
# 10953  "1119811161405448192"
# 10954  "1119810080554344448"
# 10955  "1119809906729717761"
# 10957  "1119792187993206784"
#
#                                                Tweet_URL  \
# 3      https://twitter.com/ChandaniKirinde/status/113...
# 4      https://twitter.com/vipulananda/status/1130043...
# 10     https://twitter.com/vipulananda/status/1129755...
# 13     https://twitter.com/vipulananda/status/1129449...
# 14     https://twitter.com/vipulananda/status/1129435...
# ...                                                  ...
# 10952  https://twitter.com/MarieszCader/status/111981...
# 10953  https://twitter.com/EmbarkLK/status/1119811161...
# 10954  https://twitter.com/anp66/status/1119810080554...
# ...

# %%
model_1_dataset3=tweet_df1.drop_duplicates(subset=['Screen_Name'])

# %%
model_1_dataset3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 125 entries, 3 to 10957
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Tweet_Id                    125 non-null    object
#  1   Tweet_URL                   125 non-null    object
#  2   Tweet_Posted_Time_(UTC)     125 non-null    object
#  3   Tweet_Content               125 non-null    object
#  4   Tweet_Type                  125 non-null    object
#  5   Client                      125 non-null    object
#  6   Retweets_Received           125 non-null    int64
#  7   Favourites_Received         125 non-null    int64
#  8   Tweet_Location              125 non-null    object
#  9   Tweet_Language              124 non-null    object
#  10  User_Id                     125 non-null    object
#  11  Name                        125 non-null    object
#  12  Screen_Name                 125 non-null    object
# ...

# %%
model_1_result=model_1_dataset3[['User_Id', 'Name','Screen_Name']].copy()
model_1_result['User_Id_punct'] = model_1_result['User_Id'].apply(lambda x: x.replace('"', ''))
model_1_result.head()
model_1_dataset2=model_1_result[['User_Id_punct', 'Name','Screen_Name']].copy()
model_1_dataset2.rename(columns = {'User_Id_punct':'User_Id'}, inplace = True)
model_1_dataset2.head(10)
#model_1_dataset1=model_1_dataset3['Screen_Name'].head(10)
# Out:
#                  User_Id                 Name      Screen_Name
# 3             1951067186  Chandani Kirinde 🇱🇰  ChandaniKirinde
# 4                9909452       Vipulananda 🇱🇰      vipulananda
# 15    957681564284006401       Asiri Fernando  AsiriFernandoLK
# 21   1100241609721958400          Lankanenews      lankanenews
# 22            1869917396    Wasitha Pinnawala   WasithaKeminda
# 26            4611985095           MarcMartín      MarcMartinn
# 28             122884856       Lankanorg News        LankanOrg
# 37              40320649              neetwit          Neetwit
# 163            301807277         Francanstyle     Francanstyle
# 235            114960150              Vikalpa    vikalpavoices

# %%
tweet_df = load_data()
tweet_df.head(2)


#li = ['Colombo,Sri Lanka', 'Sri Lanka', 'Colombo, Sri Lanka',]
 
pattern='Colombo,Sri Lanka |Colombo, Sri Lanka|Sri Lanka| Srilanka ðŸ‡±ðŸ‡° |Colombo|Colombo, Srilanka|Colombo Sri Lanka|Sri Lankan'

mask=tweet_df['Tweet_Location'].str.contains(pattern,case=False,na=False)
tweet_df1=tweet_df[mask]
tweet_df1

import json
col_list = tweet_df1.Screen_Name.values.tolist()
col_list

json_str = json.dumps(col_list)
json_str

a=col_list.replace("'", '"')
a



for user in json_str:
  users = api.lookup_users(screen_names =user)

  for user in users:
    print(user.screen_name, user.created_at,user.statuses_count, user.followers_count, user.friends_count, user.verified, 
user.location, user.listed_count,user.id,user.name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-71-c2b30365b922> in <module>
#      18 json_str
#      19
# ---> 20 a=col_list.replace("'", '"')
#      21 a
#      22
#
# AttributeError: 'list' object has no attribute 'replace'

# %%
my_str = "bobby 'hadz' com"

result = my_str.replace("'", '"')
print(result) # 👉️ bobby "hadz" com
# Out:
# bobby "hadz" com

# %%
csvFile = open('users.csv', 'a')
csvWriter = csv.writer(csvFile)
csvWriter.writerow(["screen_name", "created_at", "statuses_count", "followers_count", "friends_count", "verified", 
"location", "listed_count"])
# Out:
# 100

# %%
my_list = ['one', 'two', 'three']

my_str = ', '.join(f'"{item}"' for item in my_list)

print(my_str)
# Out:
# "one", "two", "three"

# %%
root_path = 'gdrive/My Drive/Colab Notebooks/'

# %%
with open('gdrive/My Drive/Colab Notebooks/usernames.txt', 'r') as f:    
   text=f.read()
vocab = sorted(set(text)) 
vocab_to_int = {c: i for i, c in enumerate(vocab)}    
int_to_vocab = dict(enumerate(vocab))    
encoded = np.array([vocab_to_int[c] for c in text], dtype=np.int32)

# %%
#users = ["BBCWorld","AzzamAmeen","SriLankaTweet","adaderana","NewsFirstSL","DailyNews_lk","MarianneDavid24","HarshadeSilvaMP","RiviraNews","Dailymirror_SL"] 

users = api.lookup_users(screen_names =["dula_aluthge"])
                         
                         
                         ["ChandaniKirinde","vipulananda","AsiriFernandoLK","lankanenews","WasithaKeminda","MarcMartinn","LankanOrg","Neetwit","Francanstyle","vikalpavoices"])
dula_aluthge
users.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0650cf3d1a4b> in <module>
#       1 user = ["BBCWorld","AzzamAmeen","SriLankaTweet","adaderana","NewsFirstSL","DailyNews_lk","MarianneDavid24","HarshadeSilvaMP","RiviraNews","Dailymirror_SL"]
#       2
# ----> 3 users = api.lookup_users(screen_names =user)
#       4
#       5
#
# NameError: name 'api' is not defined

# %%
import pandas as pd
#df = pd.DataFrame(list)

# %%
for user in users:
  print(user.screen_name, user.created_at, 
        user.statuses_count, user.followers_count, user.friends_count, user.verified, 
user.location, user.listed_count,user.id,user.name)
# Out:
# ChandaniKirinde 2013-10-10 06:53:14 50061 11129 1392 False Colombo,Sri Lanka 152 1951067186 Chandani Kirinde 🇱🇰
# vipulananda 2007-11-03 07:37:38 124277 3046 5000 False Colombo, Sri Lanka 353 9909452 Vipulananda 🇱🇰
# AsiriFernandoLK 2018-01-28 18:27:32 17718 1207 2119 False Sri Lanka 23 957681564284006401 Asiri Fernando
# lankanenews 2019-02-26 03:50:16 3123 597 1784 False Sri Lanka 0 1100241609721958400 Lankanenews
# WasithaKeminda 2013-09-16 02:07:12 80 337 546 False Pinnawala 0 1869917396 Wasitha Pinnawala
# MarcMartinn 2015-12-26 15:30:38 1820 57 155 False Sri Lanka 0 4611985095 MarcMartín
# LankanOrg 2010-03-14 06:54:48 6430 140 574 False Sri Lanka 0 122884856 Lankanorg News
# Neetwit 2009-05-15 20:06:00 191839 2934 2867 False Colombo 15 40320649 neetwit
# Francanstyle 2011-05-20 03:02:43 1611 81 347 False Sri Lanka 0 301807277 Francanstyle
# vikalpavoices 2010-02-17 04:34:35 35414 16105 151 True Colombo, Srilanka 143 114960150 Vikalpa

# %%
for user in users:
  print(user.screen_name, user.created_at, 
        user.statuses_count, user.followers_count, user.friends_count, user.verified, 
user.location, user.listed_count,user.id,user.name)

list = []
for user in users:
    #text = user._json["full_text"]

    refined_tweet = {'screen_name' : user.screen_name,
                     'User_Id' : user.id,
                     'Name':user.name,
                    'followers_count' : user.followers_count,
                    'friends_count' : user.friends_count,
                    'created_at' : user.created_at,
                    'statuses_count' : user.statuses_count,
                    'listed_count' : user.listed_count, 
                    'location' : user.location,
                    'verified' : user.verified,
                     'User_Bio':user.description}
    
    list.append(refined_tweet)




#csvWriter.writerow([user.screen_name, user.created_at, user.statuses_count, user.followers_count, user.friends_count, 
#user.verified, user.location, user.listed_count])
# Out:
# ChandaniKirinde 2013-10-10 06:53:14 50061 11129 1392 False Colombo,Sri Lanka 152 1951067186 Chandani Kirinde 🇱🇰
# vipulananda 2007-11-03 07:37:38 124277 3046 5000 False Colombo, Sri Lanka 353 9909452 Vipulananda 🇱🇰
# AsiriFernandoLK 2018-01-28 18:27:32 17718 1207 2119 False Sri Lanka 0 957681564284006401 Asiri Fernando
# lankanenews 2019-02-26 03:50:16 3123 597 1784 False Sri Lanka 0 1100241609721958400 Lankanenews
# WasithaKeminda 2013-09-16 02:07:12 80 337 546 False Pinnawala 0 1869917396 Wasitha Pinnawala
# MarcMartinn 2015-12-26 15:30:38 1820 57 155 False Sri Lanka 0 4611985095 MarcMartín
# LankanOrg 2010-03-14 06:54:48 6430 140 574 False Sri Lanka 0 122884856 Lankanorg News
# Neetwit 2009-05-15 20:06:00 191839 2934 2867 False Colombo 15 40320649 neetwit
# Francanstyle 2011-05-20 03:02:43 1611 81 347 False Sri Lanka 1 301807277 Francanstyle
# vikalpavoices 2010-02-17 04:34:35 35414 16105 151 True Colombo, Srilanka 143 114960150 Vikalpa

# %%
import pandas as pd
df = pd.DataFrame(list)

# %%
df
# Out:
#        screen_name              User_Id                 Name  followers_count  \
# 0  ChandaniKirinde           1951067186  Chandani Kirinde 🇱🇰            11129
# 1      vipulananda              9909452       Vipulananda 🇱🇰             3046
# 2  AsiriFernandoLK   957681564284006401       Asiri Fernando             1207
# 3      lankanenews  1100241609721958400          Lankanenews              597
# 4   WasithaKeminda           1869917396    Wasitha Pinnawala              337
# 5      MarcMartinn           4611985095           MarcMartín               57
# 6        LankanOrg            122884856       Lankanorg News              140
# 7          Neetwit             40320649              neetwit             2934
# 8     Francanstyle            301807277         Francanstyle               81
# 9    vikalpavoices            114960150              Vikalpa            16105
#
#    friends_count          created_at  statuses_count  listed_count  \
# ...

# %%
csvWriter.writerow([user.screen_name, user.created_at, user.statuses_count, user.followers_count, user.friends_count, 
user.verified, user.location, user.listed_count])



import pandas as pd

df.to_csv('df',sep='\t')
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

uploaded = drive.CreateFile({'title': 'sample.csv', 'mimeType':'csv'})
uploaded.SetContentFile('abc')
uploaded.Upload()

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
root_path = 'gdrive/My Drive/Colab Notebooks/'

# %%
df.to_csv('ordinary.csv')

# %%
# !cp data.csv "gdrive/My Drive/Colab Notebooks/"

# %%
# import the module
import tweepy
  
# assign the values accordingly
consumer_key = ""
consumer_secret = ""
access_token = ""
access_token_secret = ""
  
# authorization of consumer key and consumer secret
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
  
# set access to user's access key and access secret 
auth.set_access_token(access_token, access_token_secret)
  
# calling the api 
api = tweepy.API(auth)
  
# list of user_ids
user_ids = [57741058, 4802800777, 1037141442]
  
# getting the users by user_ids
users = api.lookup_users(user_ids)
  
# printing the user details
for user in users:
    print("The id is : " + str(user.id))
    print("The screen name is : " + user.screen_name, end = "\n\n")
